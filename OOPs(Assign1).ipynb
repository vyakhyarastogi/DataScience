# %%
#question1

''' A class is a logical entity used to define a new data type. 
A class is a user-defined type that describes what a particular kind of object will look like.
Thus, a class is a template or blueprint for an object. 
A class contains variables, methods, and constructors.

object:An object is an instance of a Class. 
It is an identifiable entity with some characteristics and behavior. 
Objects are the basic units of object-oriented programming.  
It may be any real-world object like a person, chair, table, pen, animal, car, etc.'''

class car:
    def speed(self):
        return "my top speed is 120km/hr"
    
#object_car is an object of class car
    
object_car=car()
object_car.speed()
# Out:
# 'my top speed is 120km/hr'

# %%
#Question2

''' Four pillars of OOPs are:
1) Polymorphism
2)Inheritance
3)Encapsulation
4)Abstraction '''


#Question3

''' __init__ function is a constructor and when object is created 
is automatically being called.'''

class car:
    def __init__(self,name,speed):
        self.name=name
        self.speed=speed
        
    def return_details(self):
        return self.name,self.speed
        
object_car=car("benz",120)
object_car.return_details()

'''ere init act as an constructor which is already been 
called when object is created'''
# Out:
# ('benz', 120)

# %%
#Question4

'''self represents the instance of the class. By using the “self”  
we can access the attributes and methods of the class in python. 
It binds the attributes with the given arguments.'''



#question5

''' Inheriance means a class inherited the properties of other class'''

#Multi-level inhertitance

class class1:
    def test_class1(self):
        return "this is a mthod inside class 1"
    
class class2(class1):
    def test_class2(self):
        return "this is a method iniode class2"
    
class class3(class2):
    def test_class3(self):
        return "this is a method inside class3"
    
object_class3=class3()
object_class3.test_class1()
object_class3.test_class2()
object_class3.test_class3()


#multiple inheritance

class
# Out:
# 'this is a method insode class3'
