# %%
#question1
#  comments are the additional readable information which are not executed
#  during program run. -->single line comment

# It can be of two types single line comment and multi line comment 

""" Multi-line comment  """
# Out:
# 'multiline comment'

# %%
#question2

variable are like container whhich stores data types.
a=15; # here a is variable

# %%
#question3
# Typecasting

a=5
print(type(a))
# Out:
# <class 'int'>

# %%
a=str(5)
print(type(a))
# Out:
# <class 'str'>

# %%
#question5
my_list=[1,2,3,4,5]
print(my_list[1:3])
# Out:
# [2, 3]

# %%
#question6
c=4+5j #complex number in python

# %%
#question7

named_age=25

# %%
#question8
named_price=9.99 # declared a variable
print(type(named_price))
# Out:
# <class 'float'>

# %%
named_name="Vyakhya Rastogi"
print(named_name)
# Out:
# Vyakhya Rastogi

# %%
string="Hello, World"
print(string[7:13])
# Out:
# World

# %%
is_student=bool(input("whether you are current student or not:"))
if(is_student):
                print("i am current student")
        
else:
                print("not a current student")
# Out:
# whether you are current student or not: true
# i am current student

# %%
#questi
